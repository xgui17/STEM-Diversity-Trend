# %% [markdown]
# # Diversity Trends of STEM Nobel Prize Winners and STEM Workforce Over Time

# %% [markdown]
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [`X`] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Names
#
# - Anh Tran
# - Jodi Roe
# - Tianyu Wang
# - Wan-Hsuan Lin
# - Xiaoyu Gui

# %% [markdown]
# # Abstract

# %% [markdown]
# &emsp;The Nobel Prize is one of the highest achievements one can receive in the academic field — however, it is no secret that the pool of laureates lacks diversity, despite our society being the complete opposite. Similarly, STEM has been a field historically dominated by white males, though recent efforts and initiatives to make the space more inclusive have become more prevalent. Consequently, we sought to compare both the workforce and Nobel laureates in the STEM fields to see if there was a trend toward more diversity for women and/or People of Color (POC) from 1990 to 2023. After comparing the proportions of gender and ethnicities, conducting the chi-squared test, and completing a correlational analysis, we conclude that there is no significant difference between Nobel Prize laureates and workforce diversity found. This is likely due to the small sample size for Nobel Prize winners and some missing demographic data. Future work could be conducted with Nobel Prize nominees, which would have a larger sample size to achieve potentially clearer and more informative results.

# %% [markdown]
# # Research Question

# %% [markdown]
# Is there a trend toward more diversity for women and people of color in the workforce compared to Nobel laureates in the STEM fields from 1990 to 2023?

# %% [markdown]
# # Background and Prior Work

# %% [markdown]
# &emsp;The Nobel Prize is one of the most established and well-known awards in the scientific field. Since 1901, the Nobel Prize has been awarded 621 times to accomplished people in Physics, Chemistry, Medicine or Physiology, Literature, Peace, and Economic Sciences. <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) However, in recent years, there have been many controversies in the pool of nominations and laureates of the Nobel Prize regarding the majority white, male-dominated nature of elite education and research institutes. Till 2018, only 20 out of 607 medals were awarded to women. <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) Neikirk et al. focused on winners in the Physiology and Medicine category and classified them on nationality, gender, and race. The research shows that the nationalities of the majority of the laureates are American. Moreover, black scientists are significantly underrepresented and there is an apparent lack of gender and racial minorities among Nobel laureates. <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3)
#
# &emsp;Furthermore, a study from 2017 analyzed the institution affiliations of the winners (ie. where they received their Ph.D/MD degree and conducted a majority of their research). It demonstrates that Nobel laureates are primarily associated with elite education and research institutes. <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4) This is significant since a disproportionate number of minorities are often underrepresented in higher education.
#
# &emsp;Both studies suggest bias toward scientists based on their nationality, gender, race, and associated institution. In our study, we aim to analyze the diversity of Nobel laureates similarly to Neikirk et al. However, differing from their study, we include other categories besides just Physiology and Medicine that would fall under the STEM label. We expanded the scope further by also comparing the diversity trends of Nobel prize winners to the actual STEM workforce. This will allow us to get a more accurate understanding of the current state of diversity in both academia and industry.
#
# &emsp;In 2019, the Nobel Prize committee addressed the lack of diversity by announcing that they would try to expand the pool of nominees in gender, ethnicity, and geography. The academy’s secretary-general, biomedical scientist Göran Hansson, said: “It looks like there is a positive trend, with more women being nominated. It’s small, but it’s a trend… With time, there will also be a gradual change in the population of scientists who are potential candidates, so that will help too.” <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2)
#
# &emsp;Hansson’s opinion is echoed in Mahmoudi et al.’s research. They calculated the likelihood of women winning the Nobel Prize over the years. The results illustrate that there is an overall increase in the percentage of female winners in all categories except Physics. This trend could be related to the rise in women participating in the STEM fields. Based on reports from the National Science Foundation, between 2011 and 2021, there was a significant increase in the representation of women and underrepresented minorities in the STEM workforce in the United States. <a name="cite_ref-6"></a>[<sup>6</sup>](#cite_note-6) However, the proportion of women in the workforce is still more significant than the percentage of women in Nobel laureates. <a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5)
#
# &emsp;While there is evidence that the gender disparity is decreasing, the issue of minority representation is still prevalent. Namely, the research does not address POC, which we strive to do in our project. We also want to compare POC representation in the Nobel Prize with the workforce to see if there is a trend similar to women in STEM.
#
#
#
# References
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) “Nobel Prize facts.” NobelPrize.org, 5 Oct. 2009, https://www.nobelprize.org/prizes/facts/nobel-prize-facts.
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Gibney, Elizabeth. “'More women are being nominated': Nobel academy head discusses diversity.” Nature, 4 Oct. 2019, https://doi.org/10.1038/d41586-019-02988-5.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Neikirk, Kit, et al. “Disparities in funding for Nobel prize awards in medicine and physiology across nationalities, races, and gender.” Journal of Cellular Physiology, 15 Jan. 2024, https://doi.org/10.1002/jcp.31157.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Schlagberger, Elisabeth Maria, et al. “United States, Europe, and Asia: Diversity in Nobel Prize-Winning Affiliations”. International Higher Education, no. 90, June 2017, pp. 12-13, doi:10.6017/ihe.2017.90.10004.
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) "Mahmoudi, Morteza, et al. “Representation of women among scientific Nobel prize nominees.” The Lancet, vol. 394, no. 10212, Nov. 2019, pp. 1905-1906, https://doi.org/10.1016/s0140-6736(19)32538-3.
# 6. <a name="cite_note-6"></a> [^](#cite_ref-6) "Diversity and STEM: Women, Minorities, and Persons with Disabilities in Science and Engineering: 2023." National Center for Science and Engineering Statistics (NCSES), National Science Foundation, 2023, https://ncses.nsf.gov/pubs/nsf23315/report.

# %% [markdown]
# # Hypothesis

# %% [markdown]
# &emsp; We predict that while the demographic of Nobel Prize winners will be diversified from 1990 to 2023 and reflect gradual changes in academia and research fields, this trend may lag behind the broader diversification observed within the general workforce, particularly regarding gender, ethnicity, and nationality. This discrepancy can be attributed to the inherently conservative nature of academic recognition as well as the time lag in acknowledging diverse contributions within the upper echelons of academia compared to more rapid shifts in workforce demographics driven by global trends, policy changes, and inclusivity efforts.

# %% [markdown]
# # Data

# %% [markdown]
# ### Data overview
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name: `nobel_prize_ethnicity`
#   - Link to the dataset: <a href="https://en.wikipedia.org/wiki/Lists_of_Nobel_laureates">original data source</a>, <a href='https://github.com/COGS108/Group038_WI24/blob/master/nobel_data_identity.csv'>github link</a>
#   - Number of observations: 144
#   - Number of variables: 4
# - Dataset #2
#   - Dataset Name: `nobel_prize_winners`
#   - Link to the dataset:  <a href="https://public.opendatasoft.com/explore/dataset/nobel-prize-laureates/table/?flg=en-us&disjunctive.category">original data source</a>, <a href='https://github.com/COGS108/Group038_WI24/blame/master/nobel_winners.csv'>github link</a>
#   - Number of observations: 1000
#   - Number of variables: 13
# - Dataset #3
#   - Dataset Name: `stem_workforce_ethnicity`, `stem_workforce_gender`
#   - Link to the dataset: <a href="https://www.nsf.gov/statistics/women/">original data source</a>, <a href='https://github.com/COGS108/Group038_WI24/blob/master/STEM_Workforce_Ethnicity.csv'>github link for ethnicity</a>, <a href='https://github.com/COGS108/Group038_WI24/blob/master/STEM_Workforce_Gender.csv'>github link for gender</a>
#   - Number of observations: 107 each
#   - Number of variables: 8 (`stem_workforce_ethnicity`), 4 (`stem_workforce_gender`)
#
# The first dataset from Wikipedia contains Nobel Prize winners from 1913 to 2023 who are Black, Latin American, Asian, and African. There are 144 observations, including 4 features: the year they won the prize, their names, their prize category, and their identity. First, we removed the observations who did not win a prize in STEM and kept winners in physics, chemistry, physiology or medicine, and economics. Then, we replaced some characters in the winners’ names to ensure they are correct, for example, we replaced 'Ã©' with 'e'. We used value_counts() to gauge how many prize winners are in each category and identities. After data cleaning and removing duplicates, we have 64 observations and 4 features: `year` (int), `name` (string), `category` (string), and `identity` (string).
#
# The second dataset we will use is a tabular dataset containing information on all Nobel Prize laureates. After dropping the unneeded columns, there are 13 variables and 1000 observations. Some important variables that we plan to use in our analysis include `firstname` (string), `surname` (string), `bornCountry` (string), `gender` (string), `year` (integer), `category` (string), which indicates the winners' demographic information and field of achievement. They can serve as proxies for analyzing trends in gender representation and geographical diversity of Nobel Prize laureates over time. Data wrangling may involve handling missing values, standardizing country names, and converting year to a datetime format for temporal analysis.
#
# As we are comparing the diversity trends in Nobel Prize laureates with STEM workforce, we need to have two datasets containing demographic diversity information on the two groups that we are focusing on. Therefore, we plan to merge dataset #1 (`nobel_prize_ethnicity`) and #2 (`nobel_prize_winners`) by the laureates' name. Although the two datasets were collected via different source, they both have demographic information on the Nobel Prize laureates. Potential string cleaning may be needed due to difference in name storage.
#
# The third dataset was found in the National Science Foundation in their respective years. However, due to it all being in different formats and our team only needed several lines from each year, we decided to input the data we need into an excel sheet and then transform into a Pandas-readable csv file. For this reason, we were able to name the variables how we would have liked prior to data cleaning, and the data is relatively clean for usage. For the `stem_workforce_ethnicity` dataset, we have 8 variables and 107 observations and the variables are `Year` (string), ` White` (string), `Asian` (string), `Black` (string), `Hispanic` (string), `American Indian` (string), `More than one race` (string), and `Category`(string). The `stem_workforce_gender` dataset have 4 variables and 107 observations and the variables are `Year` (string), `Female` (string), `Male` (string) and `Category`. Specifically,  the `Category` column in both datasets contains information about the specific STEM field the row correspond to. These fields include "Life sciences", "Computer sciences", and "Mathematical sciences".
#
# This data contains the Science and Engineering workforce’s gender and ethnicity distribution every 2 or 3 years from 1990 to 2023 and can be used to explore the changes in gender and ethnicity diversity in STEM workforce in the U.S. Data wrangling includes dealing with missing data in some years and categories, and converting strings into integers and calculating the percentages from the raw numbers. String manipulation is also needed to match the categories. Both `stem_workfroce_ethnicity` and `stem_workforce_gender` have the same year and the same source so we will be merging the two data together to provide clarity. Potential additional variables might be needed to indicate the percent changes for each variables.

# %%
# Imports
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.set_context("notebook")
sns.set_palette("deep")
plt.rcParams['figure.figsize'] = [8, 5]
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### nobel_prize_ethnicity
# First, we will examine the data on the ethnicity of Nobel Prize laureates, which has been collected from Wikipedia. Our initial step involves cleaning this data to ensure its accuracy and compatibility for subsequent merging with the `nobel_prize_winners` dataset.

# %%
# read in nobel prize ethnicity data
nobel_prize_ethnicity  = pd.read_csv('data/nobel_data_identity.csv')

# %%
# look at the Identity and Prize column 
nobel_prize_ethnicity['Identity'].unique(), nobel_prize_ethnicity['Prize'].unique()
# Out:
# (array(['Black', 'Latin American', 'Asian', 'African'], dtype=object),
#  array(['Literature', 'Peace', 'Economics', 'Chemistry',
#         'Physiology or Medicine', 'Physics'], dtype=object))

# %% [markdown]
# Since we are comparing the historic trends in diveristy within STEM workforce and Nobel Prize winners in STEM fields, we only keep information for those who have won a Nobel Prize in physics, chemistry, physiology or medicine, and economics.

# %%
# get STEM prize winners, remove Literature and Peace prize winners
cleaned_df = nobel_prize_ethnicity[nobel_prize_ethnicity['Prize'].isin(['Economics', 'Chemistry', 'Physiology or Medicine', 'Physics'])].reset_index(drop=True)

# %%
# use medicine for prize name for simplicity
def standardize_prize(prize):
    if prize == 'Physiology or Medicine':
        output = 'medicine'
    else:
        output = prize.lower()
    return output

# %%
# standardize prize
cleaned_df['Prize'] = cleaned_df['Prize'].apply(standardize_prize)

# %% [markdown]
# We also noticed that some names have special characters that need to be replaced.

# %%
# standardize name
def standardize_name(name):
    """
    A function to standardize winner names. Removes special characters.
    """
    output = name.strip().replace('Ã©', 'e').replace('Å', 'o').replace('Å', 'O')
    return output

# %%
# apply standardize name
cleaned_df['Name'] = cleaned_df['Name'].apply(standardize_name)

# %%
# checking progress
cleaned_df.head()
# Out:
#    Year                      Name      Prize        Identity
# 0  1979           W. Arthur Lewis  economics           Black
# 1  1970            Luis F. Leloir  chemistry  Latin American
# 2  1995           Mario J. Molina  chemistry  Latin American
# 3  1947  Bernardo Alberto Houssay   medicine  Latin American
# 4  1980          Baruj Benacerraf   medicine  Latin American

# %%
# number of prizes in each subject category
cleaned_df['Prize'].value_counts()
# Out:
# chemistry    23
# physics      23
# medicine     13
# economics     5
# Name: Prize, dtype: int64

# %%
# number of prizes awarded to each identity
cleaned_df['Identity'].value_counts()
# Out:
# Asian             50
# African            8
# Latin American     5
# Black              1
# Name: Identity, dtype: int64

# %%
cleaned_df.shape
# Out:
# (64, 4)

# %%
# change the columns name
cleaned_df.columns = ['year', 'name', 'category', 'identity']

# %% [markdown]
# Now our dataframe looks like this.It's important to acknowledge that our dataset, sourced from Wikipedia, distinguishes between "African" as a geographical region and "Black" as an ethnicity, leading to potential misclassification of Nobel Prize winners within this data.

# %%
cleaned_df.head()
# Out:
#    year                      name   category        identity
# 0  1979           W. Arthur Lewis  economics           Black
# 1  1970            Luis F. Leloir  chemistry  Latin American
# 2  1995           Mario J. Molina  chemistry  Latin American
# 3  1947  Bernardo Alberto Houssay   medicine  Latin American
# 4  1980          Baruj Benacerraf   medicine  Latin American

# %% [markdown]
# This is the format ideal for future merging with the dataset containing other information about Nobel Prize winners.

# %% [markdown]
# ### nobel_prize_winners
# Next up, we will look at the `nobel_prize_winners` and perform data cleaning to prepare for merging.

# %%
# load the dataset for nobel prize winners
nobel_prize_winners = pd.read_csv('data/nobel_winners.csv')

# %% [markdown]
# Similar to what we did for the previous dataset, we only keep information for those who have won a Nobel Prize in physics, chemistry, physiology or medicine, and economics in this dataset, too. The data source uses "medicine" to indicate the person have won a Nobel Prize in Physiology or Medicine, and we will continue to use it. Besides, we discard information about the winners' place of death and motivation.

# %%
# check out the dataset
print(nobel_prize_winners['category'].unique())
nobel_prize_winners.head()
# Out:
# ['physics' 'chemistry' 'peace' 'medicine' 'literature' 'economics']
#    id       firstname    surname        born        died  \
# 0   1  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10
# 1   2      Hendrik A.    Lorentz  1853-07-18  1928-02-04
# 2   3          Pieter     Zeeman  1865-05-25  1943-10-09
# 3   4           Henri  Becquerel  1852-12-15  1908-08-25
# 4   5          Pierre      Curie  1859-05-15  1906-04-19
#
#              bornCountry bornCountryCode                bornCity  \
# 0  Prussia (now Germany)              DE  Lennep (now Remscheid)
# 1        the Netherlands              NL                  Arnhem
# 2        the Netherlands              NL              Zonnemaire
# 3                 France              FR                   Paris
# 4                 France              FR                   Paris
#
#        diedCountry diedCountryCode   diedCity gender  year category  \
# 0          Germany              DE     Munich   male  1901  physics
# ...

# %%
# drop unneeded data
needed_prize = ['physics', 'chemistry', 'medicine', 'economics']
nobel_prize_winners = nobel_prize_winners.drop(columns=['diedCountry', 'diedCountryCode','diedCity',
                                                        'overallMotivation', 'share','motivation','bornCountryCode','id'])
nobel_prize_winners = nobel_prize_winners[nobel_prize_winners['category'].isin(needed_prize)]

# %%
# renaming name columns to their affiliation
nobel_prize_winners = nobel_prize_winners.rename(columns={'name':'affiliation'})

# %%
# check to see if the categories are removed
nobel_prize_winners['category'].unique()
# Out:
# array(['physics', 'chemistry', 'medicine', 'economics'], dtype=object)

# %%
# check to see if the unneeded columns are removed
nobel_prize_winners.columns
# Out:
# Index(['firstname', 'surname', 'born', 'died', 'bornCountry', 'bornCity',
#        'gender', 'year', 'category', 'affiliation', 'city', 'country'],
#       dtype='object')

# %%
nobel_prize_winners.shape
# Out:
# (739, 12)

# %%
# check for missing data
nobel_prize_winners.isna().sum()
# Out:
# firstname       0
# surname         0
# born            0
# died            0
# bornCountry     0
# bornCity        2
# gender          0
# year            0
# category        0
# affiliation     7
# city           12
# country        10
# dtype: int64

# %%
# checking dataset
nobel_prize_winners.head()
# Out:
#         firstname    surname        born        died            bornCountry  \
# 0  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10  Prussia (now Germany)
# 1      Hendrik A.    Lorentz  1853-07-18  1928-02-04        the Netherlands
# 2          Pieter     Zeeman  1865-05-25  1943-10-09        the Netherlands
# 3           Henri  Becquerel  1852-12-15  1908-08-25                 France
# 4          Pierre      Curie  1859-05-15  1906-04-19                 France
#
#                  bornCity gender  year category  \
# 0  Lennep (now Remscheid)   male  1901  physics
# 1                  Arnhem   male  1902  physics
# 2              Zonnemaire   male  1902  physics
# 3                   Paris   male  1903  physics
# 4                   Paris   male  1903  physics
#
#                                          affiliation       city  \
# 0                                  Munich University     Munich
# 1                                  Leiden University     Leiden
# ...

# %% [markdown]
# The dataset is relatively clean, with a few missing data in `affiliation`, `city` and `country` attributes that we may not use. There was no messy strings with special characters, and the string columns have uniform string formats that is easy to wrangle. The essential preprocessing steps involved handling the missing data, potentially through searching for information elsewhere or exclusion of incomplete records. Additionally, string manipulation may be needed on the `bornCountry` and `bornCity` column to standardize country names and get rid of irrelevant information.

# %%
def standardize_country(string):
    """
    A function to standardize country names.
    If a country has a new name, extract the new name from string.
    """
    if pd.isna(string):
        return np.nan
    match = re.search(r'\(now\s(.*?)\)', string)
    return match.group(1) if match else string

# %%
# clean up country and city names
nobel_prize_winners['bornCountry'] = nobel_prize_winners['bornCountry'].apply(standardize_country)
nobel_prize_winners['bornCity'] = nobel_prize_winners['bornCity'].apply(standardize_country) # same logic applies to city names

# %%
nobel_prize_winners.head()
# Out:
#         firstname    surname        born        died      bornCountry  \
# 0  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10          Germany
# 1      Hendrik A.    Lorentz  1853-07-18  1928-02-04  the Netherlands
# 2          Pieter     Zeeman  1865-05-25  1943-10-09  the Netherlands
# 3           Henri  Becquerel  1852-12-15  1908-08-25           France
# 4          Pierre      Curie  1859-05-15  1906-04-19           France
#
#      bornCity gender  year category  \
# 0   Remscheid   male  1901  physics
# 1      Arnhem   male  1902  physics
# 2  Zonnemaire   male  1902  physics
# 3       Paris   male  1903  physics
# 4       Paris   male  1903  physics
#
#                                          affiliation       city  \
# 0                                  Munich University     Munich
# 1                                  Leiden University     Leiden
# 2                               Amsterdam University  Amsterdam
# ...

# %% [markdown]
# ### Merge nobel_prize_ethnicity and nobel_prize_winners
#
# We would like to add the information of the ethnicity of nobel prize winners to the dataset that contains all other information. We noticed that the names in the two datasets are not consistently formatted and can not be matched easily despite of some cleaning. Therefore, we decided to merge by year and prize combination, and filter the merged dataset by matches in either `firstname` or `surname` to ensure the accuracy.

# %%
# merge dataset of ethnicity of noble prize winners into existing dataset 
merge_nobel = pd.merge(cleaned_df, nobel_prize_winners, on=['year', 'category'], how='right')

# %%
# checking for the ones that were not matched
no_ethnicity_info = merge_nobel[(merge_nobel['identity'].isna())] 
no_ethnicity_info.shape
# Out:
# (615, 14)

# %%
# checking for the ones with a match in year/prize
ethnicity_info = merge_nobel[(merge_nobel['identity'].notna())] 
ethnicity_info.shape
# Out:
# (159, 14)

# %%
# determine which are actual matches and set the other ones to null
ethnicity_info['keep'] = ethnicity_info.apply(lambda x: x['surname'] in x['name'] or x['firstname'] in x['name'], axis=1)
# if the name does not match, we will assign it to NaN
ethnicity_info.loc[~ethnicity_info['keep'], 'identity'] = np.nan

# %% [markdown]
# Duplicates occur when multiple people who shared the same prize in the same year are both in our ethnicity dataset. Thus, we will drop them to avoid conflicts.

# %%
# keeping only the needed ethnicity
needed_ethnicity = ethnicity_info[ethnicity_info['keep']][['firstname','surname','identity','year']]

# %%
# checking for any duplicated rows
needed_ethnicity[needed_ethnicity.duplicated(subset=['firstname','surname','year'])]
# Out:
# Empty DataFrame
# Columns: [firstname, surname, identity, year]
# Index: []

# %%
# merging the data from needed_ethnicity back into a new final_nobel_prize dataframe
final_nobel_prize = nobel_prize_winners.merge(needed_ethnicity, on=['firstname','surname','year'], how='left')

# %%
final_nobel_prize.identity.notna().sum()
# Out:
# 64

# %% [markdown]
# Final result of merged nobel_prize_ethnicity and nobel_prize winner!

# %%
# A peak at how our dataset now looks like
final_nobel_prize.iloc[710:715]
# Out:
#     firstname      surname        born        died bornCountry      bornCity  \
# 710    Robert       Wilson  1937-05-16  0000-00-00         USA     Geneva NE
# 711     David       Julius  1955-11-04  0000-00-00         USA   New York NY
# 712     Ardem  Patapoutian  1967-00-00  0000-00-00     Lebanon        Beirut
# 713   Syukuro       Manabe  1931-09-21  0000-00-00       Japan  Shingu Ehime
# 714     Klaus   Hasselmann  1931-10-25  0000-00-00     Germany       Hamburg
#
#     gender  year   category                           affiliation  \
# 710   male  2020  economics                   Stanford University
# 711   male  2021   medicine              University of California
# 712   male  2021   medicine                      Scripps Research
# 713   male  2021    physics                  Princeton University
# 714   male  2021    physics  Max Planck Institute for Meteorology
#
#                  city  country identity
# 710       Stanford CA      USA      NaN
# ...

# %%
final_nobel_prize.to_csv('data/final_nobel_prize.csv')

# %% [markdown]
# We have uploaded the merged final_nobel_prize dataset to <a href='https://github.com/COGS108/Group038_WI24/blob/master/final_nobel_prize'>github</a>. For future analysis, we will use this dataset directly.

# %% [markdown]
# Next, we will look at the `stem_workforce_ethnicity` and `stem_workforce_gender`, clean it and put it in a format that we are able to merge it similar to what we did for nobel prize data.

# %% [markdown]
# ### stem_workforce

# %%
# read in stem_workforce csv files
stem_workforce_ethnicity = pd.read_csv('data/STEM_Workforce_Ethnicity.csv')
stem_workforce_gender = pd.read_csv('data/STEM_Workforce_Gender.csv')

# %% [markdown]
# Checking out data for both files.

# %%
stem_workforce_ethnicity.shape
# Out:
# (107, 8)

# %%
stem_workforce_gender.shape
# Out:
# (107, 4)

# %%
stem_workforce_ethnicity.tail()
# Out:
#      Year Hispanic American Indian    Asian   Black      White  \
# 102  2021   23,000               -   72,000  32,000    237,000
# 103  2021   32,000           1,000   61,000  16,000    288,000
# 104  2021   27,000               -   15,000  12,000    216,000
# 105  2021   54,000               -   42,000  32,000    296,000
# 106  2021  178,000           2,000  316,000  65,000  1,345,000
#
#     More than one race                                 Category
# 102              4,000  Mathematical sciences
# 103              9,000                        Physical sciences
# 104              9,000                              Psychology
# 105              7,000                          Social sciences
# 106             36,000        Engineering

# %%
stem_workforce_gender.tail()
# Out:
#      Year   Female       Male                                 Category
# 102  2021  147,000    222,000  Mathematical sciences
# 103  2021  135,000    273,000                        Physical sciences
# 104  2021  205,000     75,000                              Psychology
# 105  2021  228,000    204,000                          Social sciences
# 106  2021  312,000  1,636,000        Engineering

# %%
# looking at the data type for both stem_workforce_ethnicity and stem_workforce_gender)
print(stem_workforce_ethnicity.info(), stem_workforce_gender.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                107 non-null    int64
#  1   Hispanic            107 non-null    object
#  2   American Indian     106 non-null    object
#  3   Asian               107 non-null    object
#  4   Black               107 non-null    object
#  5   White               107 non-null    object
#  6   More than one race  42 non-null     object
#  7   Category            107 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 6.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      107 non-null    int64
#  1   Female    107 non-null    object
#  2   Male      107 non-null    object
# ...

# %% [markdown]
# The data type for both `stem_workforce_gender` and `stem_workforce_ethnicity` are both object type and needed to be converted into int. This would mean that we need to get rid of blank space and commas.

# %%
# standardize the columns, ensuring correct data type
def standardize_num(df):
    """
    Turning String into int
    """
    if isinstance(df, str):
        if df.strip() == '-':
            return np.nan
        return float(df.strip().replace(',',''))
    else:
        return df

# %%
ethnicities = stem_workforce_ethnicity.columns[1:-1]
genders = ['Female', 'Male']

# %%
# apply standardize_num to stem_workforce_ethnicity
for i in ethnicities:
    stem_workforce_ethnicity[i] = stem_workforce_ethnicity[i].apply(standardize_num)

# %%
# apply standarize_num to stem_workforce_gender
for i in genders:
    stem_workforce_gender[i] = stem_workforce_gender[i].apply(standardize_num)

# %%
stem_workforce_gender.Category.unique()
# Out:
# array(['Total', 'Engineering', 'Math/computer science:',
#        'Natural science:', 'Social science:',
#        'Computer/mathematical sciences.', 'Life sciences',
#        'Physical sciences', 'Social sciences', 'Life & physical sciences',
#        'Psychology', 'Computer sciences         ',
#        'Mathematical sciences                  ', 'Psychology ',
#        'Engineering                      '], dtype=object)

# %% [markdown]
# Some notable points when cleaning `Category` column that may lead to bias:
#
# <ul>
#   <li>In 2000, life science and physical science were put together. This is an only case, so we categorized this into life science.</li>
#   <li>Math and computer science were put together.</li>
#   <li>Psychology only emerged as a separate category after 2000, but we combined it with the social science category for simplicity.</li>
# </ul>
#
# Below we standardize the STEM category strings into uniform forms by getting rid of the spaces, grouping certain categories together, and using lower cases.

# %%
def standardize_cat_stem(string):
    """
    Standardize the category column, aggregate similar ones together and clean string
    """
    string = string.strip().lower().replace(':','')
    if 'math' in string or 'computer' in string:
        output = 'math/cs'
    elif 'life' in string:
        output = 'life science'
    elif string == 'psychology' or 'social' in string:
        output = 'social sciences'
    else:
        output = string
    return output

# %%
# apply standardize_cat_stem to both stem_workforce_ethnicity and stem_workforce_gender
stem_workforce_gender['Category'] = stem_workforce_gender['Category'].apply(standardize_cat_stem)
stem_workforce_ethnicity['Category'] = stem_workforce_ethnicity['Category'].apply(standardize_cat_stem)

# %%
# checking progress
stem_workforce_gender.Category.unique()
# Out:
# array(['total', 'engineering', 'math/cs', 'natural science',
#        'social sciences', 'life science', 'physical sciences'],
#       dtype=object)

# %%
# adjust column order
stem_workforce_gender = stem_workforce_gender[['Category', 'Year', 'Female', 'Male']]
stem_workforce_ethnicity = stem_workforce_ethnicity[['Category', 'Year', 'Hispanic', 'American Indian', 'Asian', 'Black', 'White',
       'More than one race' ]]

# %%
# creating new df for gender that are group by category and year
stem_workforce_gender_final = stem_workforce_gender.groupby(['Category', 'Year']).sum().reset_index()

# %%
# creating new df for ethnicity that are group by category and year
stem_workforce_ethnicity_final = stem_workforce_ethnicity.groupby(['Category', 'Year']).sum().reset_index()

# %%
stem_workforce_ethnicity_final.tail()
# Out:
#    Category  Year  Hispanic  American Indian      Asian     Black      White  \
# 83    total  2013  341000.0          11000.0   966000.0  268000.0  3961000.0
# 84    total  2015  387000.0          10000.0  1321000.0  308000.0  4267000.0
# 85    total  2017  505000.0          14000.0  1338000.0  382000.0  4397000.0
# 86    total  2019  564000.0              0.0  1543000.0  379000.0  4784000.0
# 87    total  2021  692000.0          10000.0  1665000.0  399000.0  4943000.0
#
#     More than one race
# 83                 0.0
# 84                 0.0
# 85                 0.0
# 86                 0.0
# 87                 0.0

# %%
stem_workforce_gender_final.tail()
# Out:
#    Category  Year     Female       Male
# 83    total  2013  1639000.0  4003000.0
# 84    total  2015  1818000.0  4590000.0
# 85    total  2017  1966000.0  4803000.0
# 86    total  2019  2193000.0  5274000.0
# 87    total  2021  2300000.0  5594000.0

# %% [markdown]
# Checking the results, the columns for both `stem_workforce_ethnicity` and `stem_workforce_gender` are in the same general order, the numbers are float, and the categories with similar names are combined. Great!

# %% [markdown]
# Next up, we creating a percent columns for `stem_workforce_ethnicity` and `stem_workforce_gender` for later analysis.

# %%
def percent_cal(df):
    """
    Calculate the percent of each categories in dataframe
    """
    df = df.copy()
    sum_row = df.drop(['Year','Category'], axis = 1).sum(axis = 1)
    for i in df.columns:
        if i == 'Year' or i == 'Category':
            pass
        else:
            df[f'{i}_percentage'] = df[i]/sum_row            
    return df

# %%
# add percentage columns to the datasets 
stem_workforce_gender_final = percent_cal(stem_workforce_gender_final)
stem_workforce_ethnicity_final = percent_cal(stem_workforce_ethnicity_final)

# %%
# merging two data together
stem_workforce = pd.merge(stem_workforce_ethnicity_final,stem_workforce_gender_final,on = ['Year', 'Category'])

# %%
stem_workforce.head()
# Out:
#       Category  Year  Hispanic  American Indian     Asian    Black      White  \
# 0  engineering  1990   54600.0           4700.0  119900.0  60000.0  1474900.0
# 1  engineering  1993   39000.0           3000.0  132000.0  37000.0  1128000.0
# 2  engineering  1995   42100.0           3400.0  137400.0  34300.0  1120900.0
# 3  engineering  1997   48600.0           3900.0  152900.0  36400.0  1155100.0
# 4  engineering  1999   49100.0           4100.0  156600.0  37700.0  1122400.0
#
#    More than one race  Hispanic_percentage  American Indian_percentage  \
# 0                 0.0             0.031853                    0.002742
# 1                 0.0             0.029126                    0.002240
# 2                 0.0             0.031463                    0.002541
# 3                 0.0             0.034791                    0.002792
# 4                 0.0             0.035842                    0.002993
#
#    Asian_percentage  Black_percentage  White_percentage  \
# ...

# %%
stem_workforce.to_csv('data/final_stem_workforce.csv')

# %% [markdown]
# Awesome! The final data for stem_workforce are in the order we wanted. We have uploaded the merged final_stem_workforce dataset to <a href='https://github.com/COGS108/Group038_WI24/blob/master/final_stem_workforce.csv'>github</a> and will use this dataset directly for the next step of analysis.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Section 1: EDA for final_nobel_prize

# %% [markdown]
# In this section, we will aim to understand the components of the `final_nobel_prize` data set by identifying relationships, visualizing these through graphs, and analyzing what the results could potentially mean for our hypothesis.

# %%
# read in final_nobel_prize
final_nobel_prize_df = pd.read_csv('data/final_nobel_prize.csv', index_col=0)
final_nobel_prize_df.head()
# Out:
#         firstname    surname        born        died      bornCountry  \
# 0  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10          Germany
# 1      Hendrik A.    Lorentz  1853-07-18  1928-02-04  the Netherlands
# 2          Pieter     Zeeman  1865-05-25  1943-10-09  the Netherlands
# 3           Henri  Becquerel  1852-12-15  1908-08-25           France
# 4          Pierre      Curie  1859-05-15  1906-04-19           France
#
#      bornCity gender  year category  \
# 0   Remscheid   male  1901  physics
# 1      Arnhem   male  1902  physics
# 2  Zonnemaire   male  1902  physics
# 3       Paris   male  1903  physics
# 4       Paris   male  1903  physics
#
#                                          affiliation       city  \
# 0                                  Munich University     Munich
# 1                                  Leiden University     Leiden
# 2                               Amsterdam University  Amsterdam
# ...

# %% [markdown]
# The NaN values for `identity` indicates ethnicities that are considered white from European and North-American countries. For the purpose of our analysis, we will label them `Non-POC`, since their ethnicities may vary but are not regarded as minorities. Thus, the categories we will work with throughout are the following: Asian, African, Latin American, Black, and Non-POC.

# %%
# assigning Non-POC to people who are not Asian, African, Latin American, or Black
if final_nobel_prize_df['identity'].isnull().any():
    final_nobel_prize_df.loc[final_nobel_prize_df['identity'].isnull(), 'identity'] = 'Non-POC'
    
final_nobel_prize_df.head()
# Out:
#         firstname    surname        born        died      bornCountry  \
# 0  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10          Germany
# 1      Hendrik A.    Lorentz  1853-07-18  1928-02-04  the Netherlands
# 2          Pieter     Zeeman  1865-05-25  1943-10-09  the Netherlands
# 3           Henri  Becquerel  1852-12-15  1908-08-25           France
# 4          Pierre      Curie  1859-05-15  1906-04-19           France
#
#      bornCity gender  year category  \
# 0   Remscheid   male  1901  physics
# 1      Arnhem   male  1902  physics
# 2  Zonnemaire   male  1902  physics
# 3       Paris   male  1903  physics
# 4       Paris   male  1903  physics
#
#                                          affiliation       city  \
# 0                                  Munich University     Munich
# 1                                  Leiden University     Leiden
# 2                               Amsterdam University  Amsterdam
# ...

# %%
final_nobel_prize_df.describe()
# Out:
#               year
# count   739.000000
# mean   1976.682003
# std      33.184919
# min    1901.000000
# 25%    1955.000000
# 50%    1982.000000
# 75%    2004.000000
# max    2023.000000

# %% [markdown]
# `year` was the only numeric column in `final_nobel_prize_df`. Since we would like to investigate the trends, we tread `year` as numeric in our analysis.

# %%
# number of unique values in the categorical columns
final_nobel_prize_df[['bornCountry','bornCity','gender','category','affiliation','city','country','identity']].nunique()
# Out:
# bornCountry     57
# bornCity       484
# gender           2
# category         4
# affiliation    322
# city           191
# country         29
# identity         5
# dtype: int64

# %%
# Check for numbers of STEM Nobel winners in different gender groups
final_nobel_prize_df['gender'].value_counts()
# Out:
# male      710
# female     29
# Name: gender, dtype: int64

# %%
# Check for numbers of STEM Nobel winners in different ethnicity groups
final_nobel_prize_df['identity'].value_counts()
# Out:
# Non-POC           675
# Asian              50
# African             8
# Latin American      5
# Black               1
# Name: identity, dtype: int64

# %%
# focusing on gender, category and identity columns
for col in ['gender', 'category', 'identity']:
    print(f"Unique values in {col}:")
    print(final_nobel_prize_df[col].unique())
# Out:
# Unique values in gender:
# ['male' 'female']
# Unique values in category:
# ['physics' 'chemistry' 'medicine' 'economics']
# Unique values in identity:
# ['Non-POC' 'Asian' 'African' 'Latin American' 'Black']

# %% [markdown]
# ### Ages of Nobel Prize Winners at the Time of Award

# %% [markdown]
# There are some missing months and days when we look at the `born` and `died` attributes, so we decided to only keep the born and die year. If the person is not dead (which is represented by "0000-00-00" in the original dataset), we leave their `died` attribute blank.

# %%
final_nobel_prize_df['born'] = final_nobel_prize_df['born'].apply(lambda x: int(x[:4]))
final_nobel_prize_df['died'] = final_nobel_prize_df['died'].apply(lambda x: int(x[:4]))
final_nobel_prize_df.loc[final_nobel_prize_df['died']==0,'died'] = np.nan

# %%
# the age when they were awarded
final_nobel_prize_df['award_age'] = final_nobel_prize_df['year'] - final_nobel_prize_df['born']

# %% [markdown]
# Finding out who is the youngest and oldest winner.

# %%
youngest = final_nobel_prize_df.loc[final_nobel_prize_df['award_age'].idxmin(), ['firstname','surname']]
print("Youngest winner: "+str(youngest[0])+' '+str(youngest[1]))
print("Youngest age: " + str(final_nobel_prize_df['award_age'].min()))
# Out:
# Youngest winner: Lawrence Bragg
# Youngest age: 25

# %%
oldest = final_nobel_prize_df.loc[final_nobel_prize_df['award_age'].idxmax(), ['firstname','surname']]
print("Oldest winner: "+str(oldest[0])+' '+str(oldest[1]))
print("Oldest age: " + str(final_nobel_prize_df['award_age'].max()))
# Out:
# Oldest winner: John Goodenough
# Oldest age: 97

# %%
# Histogram of Age when awarded Nobel Prize (STEM only)
sns.histplot(data=final_nobel_prize_df, x='award_age', stat='probability')
plt.title('Histogram of Age when Awarded Nobel Prize (STEM only)')
plt.xlabel('Award Age')
plt.show()

# %% [markdown]
# The histogram displays the distribution of age when an individual was awarded a Nobel Prize in the STEM fields. It seems to be a normal distribution!

# %%
# Scatter plot of year vs. the winners' age
fig, ax = plt.subplots()
x, y=final_nobel_prize_df['year'],final_nobel_prize_df['award_age']
ax.scatter(x, y, alpha=0.7)
b, a = np.polyfit(x, y, deg=1)
xseq = np.linspace(1901, 2025, num=100)
ax.plot(xseq, a + b * xseq, color='black', lw=2.5)
plt.title('Age of STEM Nobel Laureates Over Time')
plt.xlabel('Year')
plt.ylabel("Winners' Age")
plt.show()

# %% [markdown]
# Applying a linear regression line shows that the winners tend to be older as the years go by. We can also see that there are more dense space around the 1960 onward, which suggests that there are generally more STEM Nobel prize winners per year since then.

# %% [markdown]
# ### Countries with Most STEM Nobel Winners

# %%
# the top 10 countries where most Nobel Prize winners live
country_nobel = final_nobel_prize_df['country'].value_counts().sort_values()[-10:].to_frame().reset_index()
country_nobel.columns=['country','count']
final_nobel_prize_df['country'].value_counts()[:10]
# Out:
# country
# USA                  382
# United Kingdom        93
# Germany               72
# France                37
# Switzerland           24
# Sweden                18
# Japan                 17
# the Netherlands       10
# Denmark                9
# USSR (now Russia)      9
# Name: count, dtype: int64

# %%
# Bar plot of the top 10 countries with most Nobel Prize winners
plt.barh(country_nobel['country'], country_nobel['count'])
ax.invert_yaxis()
plt.ylabel('country')
plt.title('The Top 10 countries where Nobel Prize Winners Live')
plt.xlabel('Nobel Prize Winners Count')
plt.ylabel('Countries')
plt.show()

# %% [markdown]
# Majority of winners have been from USA. Most of the winners are from European countries predominantly, except for Japan.

# %% [markdown]
# ### **1901-2023** Gender and Ethnicity Distribution of the STEM Nobel Prize Winners

# %%
# Lineplot of Nobel laureates Gender Distribution over 1901-2023
year_gender = final_nobel_prize_df.groupby(['year', 'gender']).count()['category'].unstack()
for index, value in year_gender['female'].items():
    if pd.isna(value):
        year_gender['female'][index] = 0
year_gender = year_gender.reset_index()

plt.figure(figsize=(10, 6))
plt.plot(year_gender['year'], year_gender['female'], marker='.', linestyle='-', label='female', color = 'coral')
plt.plot(year_gender['year'], year_gender['male'], marker='.', linestyle='-', label='male', color = 'skyblue')
plt.title('Nobel Winner Gender Diversity Trend over 1901-2023')
plt.grid(True)
plt.legend()
plt.xlabel('Year')
plt.ylabel('Nobel Prize Winners Count')
plt.show()

# %% [markdown]
# In the Nobel Winner Gender Diversity Trend over the 1901-2023 graph, we can see that it is mainly dominated by male winners. There was a lower number of winners from 1901-1950 compared to 1950 onwards, where we see that there are a higher number of winners. This can be due to the fact that each Nobel Prize was sometimes awarded to more than one person. We can also see that female winners are few to none but increased substantially from 2000 onward.

# %%
# define a dictionary to make sure colors corresponding to each ethnicity in our visualization are uniform
ethnicity_palette = {'Non-POC': '#6A5ACD', 'Asian':'#DC143C', 'Black':'#F4A460', 'Latin American':'#CD853F', 'African':'#008080'}

# %%
# Lineplot of Nobel laureates Ethnicity Distribution over 1901-2023
year_ethnicity = final_nobel_prize_df.groupby(['year', 'identity']).count()['category'].unstack().fillna(0).reset_index()

plt.figure(figsize=(10, 6))
for col in year_ethnicity.columns[1:]:
    if col in ethnicity_palette.keys():
        color=ethnicity_palette[col]
        plt.plot(year_ethnicity['year'], year_ethnicity[col], marker='.', linestyle='-', label=col, color=color)
    else:
        plt.plot(year_ethnicity['year'], year_ethnicity[col], marker='.', linestyle='-', label=col)
plt.title('Nobel Winner Ethnicity Diversity Trend over 1901-2023')
plt.grid(True)
plt.legend()
plt.xlabel('Year')
plt.ylabel('Nobel Prize Winners Count')
plt.show()

# %% [markdown]
# Across 1901-2023, Non-POC makes up the majority of Nobel Prize winners. While there are some variations of increases and decreases, they are consistently higher than the other ethnicities. There was no representations of POC until around 1930 and more representations of POC were observed around 1960 onwards. Asians see the biggest increase among POC ethnicity groups.

# %%
# Barplot of ethnicity colored by gender
ax = sns.countplot(data=final_nobel_prize_df, x='identity', hue='gender', palette=['skyblue','coral'])
plt.xlabel('Ethnicity')
ax.set_title('1901-2023 Nobel Winner Gender Distribution Across Ethnic Groups')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Across the ethnicities, there are far more males than females represented. There is a lack of diversity of both POC and female individuals, with an overwhelming majority of winners being Non-POC males. There is a severe lack of POC females represented.
#
# The graph visually shows that there is the least representation in the 'Black' category and some Asian female winners. Taking a closer look, we find that there is only one Black male and two Asian female Nobel Prize winners out of around 1000 individuals. The two females mentioned have won in the 1990-2023 time frame that we wanted to see in our final analysis.
#
# Also, there were no African female and Latin American female STEM Nobel Prize winners in our dataset.

# %%
# Number of Black Nobel Prize winners in 1901-2023
black_winner = final_nobel_prize_df[final_nobel_prize_df['identity'] == 'Black']
print(black_winner.shape[0])
black_winner
# Out:
# 1
#       firstname surname  born    died  bornCountry  bornCity gender  year  \
# 475  Sir Arthur   Lewis  1915  1991.0  Saint Lucia  Castries   male  1979
#
#       category           affiliation          city country identity  award_age
# 475  economics  Princeton University  Princeton NJ     USA    Black         64

# %%
# Number of Asian female Nobel Prize winners
asian_female = final_nobel_prize_df[(final_nobel_prize_df['identity'] == 'Asian') & (final_nobel_prize_df['gender'] == 'female')]
print(asian_female.shape[0])
asian_female
# Out:
# 2
#     firstname surname  born  died bornCountry         bornCity  gender  year  \
# 601    Ada E.  Yonath  1939   NaN      Israel        Jerusalem  female  2009
# 653    Youyou      Tu  1930   NaN       China  Zhejiang Ningbo  female  2015
#
#       category                                    affiliation     city  \
# 601  chemistry                  Weizmann Institute of Science  Rehovot
# 653   medicine  China Academy of Traditional Chinese Medicine  Beijing
#
#     country identity  award_age
# 601  Israel    Asian         70
# 653   China    Asian         85

# %%
# Number of Latin American female Nobel Prize winners
latin_american_female = final_nobel_prize_df[(final_nobel_prize_df['identity'] == 'Latin American') & (final_nobel_prize_df['gender'] == 'female')]
print(latin_american_female.shape[0])
# Out:
# 0

# %%
# Number of African female Nobel Prize winners
african_female = final_nobel_prize_df[(final_nobel_prize_df['identity'] == 'African') & (final_nobel_prize_df['gender'] == 'female')]
print(african_female.shape[0])
# Out:
# 0

# %% [markdown]
# ### **1990-2023** Gender and Ethnicity Distribution of the Nobel Prize Winners
# We will shorten the time period to more accurately represent the recent trends in diversity. We chose 1990-2023 since the STEM workforce data we will be comparing the Nobel Prize winners to only encompasses this time span as well. Here are some key findings below:

# %%
# Zooming in on 1990-2023
final_df = final_nobel_prize_df[final_nobel_prize_df['year'] >= 1990]
final_df.head()
# Out:
#          firstname    surname  born    died bornCountry              bornCity  \
# 137      Jerome I.   Friedman  1930     NaN         USA            Chicago IL
# 138       Henry W.    Kendall  1926  1999.0         USA             Boston MA
# 139     Richard E.     Taylor  1929  2018.0      Canada  Medicine Hat Alberta
# 140  Pierre-Gilles  de Gennes  1932  2007.0      France                 Paris
# 141        Georges    Charpak  1924  2010.0      Poland             Dabrovica
#
#     gender  year category                                  affiliation  \
# 137   male  1990  physics  Massachusetts Institute of Technology (MIT)
# 138   male  1990  physics  Massachusetts Institute of Technology (MIT)
# 139   male  1990  physics                          Stanford University
# 140   male  1991  physics                            Collège de France
# 141   male  1992  physics       École Supérieure de Physique et Chimie
#
#              city country identity  award_age
# ...

# %%
# Nobel laureates across identity, award categories, and gender
grouped = final_df.groupby(['identity', 'category', 'gender']).size().unstack()

# %%
ax = sns.countplot(data=final_df, x='category', hue='identity', palette='muted')
ax.set_title('1990-2023 Ethnicity Distribution in Nobel Prize Categories')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Here is a breakdown of winners' ethnicities in different Nobel Prize categories. We can see that all categories are dominated by Non-POC, with Asians having more winners than any other POC during 1990-2023. The 1990-2023 graph shows a good percentage of winners are Asian representing the POC.

# %% [markdown]
# #### Trend in Gender and Ethnicity Distribution between 1990 and 2023

# %%
year_gender = final_df.groupby(['year', 'gender']).count()['category'].unstack()
for index, value in year_gender['female'].items():
    if pd.isna(value):
        year_gender['female'][index] = 0
year_gender = year_gender.reset_index()

# %%
# Lineplot of Nobel laureates Gender Distribution over 1990-2023
plt.figure(figsize=(10, 6))
plt.plot(year_gender['year'], year_gender['female'], marker='.', linestyle='-', label='female', color = 'coral')
plt.plot(year_gender['year'], year_gender['male'], marker='.', linestyle='-', label='male', color = 'skyblue')
plt.title('Nobel Winner Gender Diversity Trend over 1990-2023')
plt.grid(True)
plt.legend()
plt.xlabel('Year')
plt.ylabel('Nobel Prize Winners Count')
plt.show()

# %% [markdown]
# The distribution is similar to the one for 1901-2023, with the majority of Nobel laureates being Non-POC male. However, one significant difference we notice is that there are no Black Nobel Prize Winners in the STEM fields between 1990-2023. In 2005-2023, there is a spike in female representation. However, there are consistently higher numbers of males than females over time.

# %%
year_ethnicity = final_df.groupby(['year', 'identity']).count()['category'].unstack().fillna(0).reset_index()

# %%
# Lineplot of Nobel laureates Ethnicity Distribution over 1990-2023
plt.figure(figsize=(10, 6))
for col in year_ethnicity.columns[1:]:
    if col in ethnicity_palette.keys():
        color=ethnicity_palette[col]
        plt.plot(year_ethnicity['year'], year_ethnicity[col], marker='.', linestyle='-', label=col, color=color)
    else:
        plt.plot(year_ethnicity['year'], year_ethnicity[col], marker='.', linestyle='-', label=col, color=color)
plt.title('Nobel Winner Ethnicity Diversity Trend over 1990-2023')
plt.grid(True)
plt.legend()
plt.xlabel('Year')
plt.ylabel('Nobel Prize Winners Count')
plt.show()

# %% [markdown]
# Again, the pool of winners is dominated by Non-POC but with a significant increase in Asians, Latin Americans, and Africans by far have the least representation and no Black representation.
#
# Note: These two line plots are plotted based on the number of people winning the Nobel Prize winners instead of the percentage because the percentage of winners for each ethnicity is very messy and doesn't translate well onto the graph.

# %% [markdown]
# **Overall, our EDA of the Nobel Prize dataset show that there is a lack of diversity, with Non-POC making up the majority regardless of gender.**

# %% [markdown]
# ## Section 2: EDA for final_stem_workforce
#
# In this section, we will the same thing as we did to `final_nobel_prize` and understand the components of the `final_stem_workforce` set by identifying, graphing, and analyzing any relationships we discover.
#
# "Native Hawaiian or Other Pacific Islander" sometimes have too small of amount that there is no specific statistic, so we excluded them from the analysis due to the lack of data.
#
# <!-- Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context. -->

# %%
# read in the prepared dataset
final_stem_workforce = pd.read_csv('final_stem_workforce.csv', index_col=0)

# %%
# create a df with only percentages
stem_percentage = pd.concat([final_stem_workforce[['Category', 'Year']], final_stem_workforce[[col for col in final_stem_workforce.columns if 'percent' in col]]], axis=1)

# %%
final_stem_workforce.head()
# Out:
#       Category  Year  Hispanic  American Indian     Asian    Black      White  \
# 0  engineering  1990   54600.0           4700.0  119900.0  60000.0  1474900.0
# 1  engineering  1993   39000.0           3000.0  132000.0  37000.0  1128000.0
# 2  engineering  1995   42100.0           3400.0  137400.0  34300.0  1120900.0
# 3  engineering  1997   48600.0           3900.0  152900.0  36400.0  1155100.0
# 4  engineering  1999   49100.0           4100.0  156600.0  37700.0  1122400.0
#
#    More than one race  Hispanic_percentage  American Indian_percentage  \
# 0                 0.0             0.031853                    0.002742
# 1                 0.0             0.029126                    0.002240
# 2                 0.0             0.031463                    0.002541
# 3                 0.0             0.034791                    0.002792
# 4                 0.0             0.035842                    0.002993
#
#    Asian_percentage  Black_percentage  White_percentage  \
# ...

# %%
# most of the columns in our dataset are continuous
final_stem_workforce.describe()
# Out:
#               Year       Hispanic  American Indian         Asian  \
# count    88.000000      88.000000        88.000000  8.800000e+01
# mean   2005.977273   93988.636364      3606.818182  2.784773e+05
# std       9.603612  126083.435641      4091.364482  3.754508e+05
# min    1990.000000    5000.000000         0.000000  8.700000e+03
# 25%    1997.000000   16625.000000      1000.000000  3.965000e+04
# 50%    2006.000000   42050.000000      2000.000000  1.179500e+05
# 75%    2015.000000  116175.000000      4025.000000  3.327750e+05
# max    2021.000000  692000.000000     19000.000000  1.665000e+06
#
#                Black         White  More than one race  Hispanic_percentage  \
# count      88.000000  8.800000e+01           88.000000            88.000000
# mean    76231.818182  1.224144e+06         7977.272727             0.052081
# std     92623.393368  1.256875e+06        17081.264370             0.024028
# ...

# %% [markdown]
# To account for missing data, we filled in any blanks with a 0 to have no missing values. However, this may introduce bias since it doesn't reflect the actual representation of STEM workers who are American Indians and more than one race.
#
# Note: in the original dataset, two types of special marks, both replaced with 0 in our dataset
# - D = not available due to confidentiality
# - S = too small less than 500

# %%
final_stem_workforce.isna().sum().sum()
# Out:
# 0

# %%
final_stem_workforce['Category'].unique()
# Out:
# array(['engineering', 'life science', 'math/cs', 'natural science',
#        'physical sciences', 'social sciences', 'total'], dtype=object)

# %% [markdown]
# ### Growth in the STEM Workforce

# %%
final_stem_workforce['total_num'] = final_stem_workforce[['Hispanic', 'American Indian', 'Asian', 'Black', 'White','More than one race']].sum(axis=1)
stem_workforce_total = final_stem_workforce[final_stem_workforce['Category'] == 'total'][['Year','total_num']]

# %%
# Line plot of total number of STEM workforce
plt.figure(figsize=(8, 6))
plt.plot(stem_workforce_total['Year'], stem_workforce_total['total_num'], marker='.', linestyle='-', label=col)
plt.title('Trend in Number of STEM Workforce Workers from 1990-2023')
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('STEM Workers Count')
plt.show()

# %%
total_1990 = stem_workforce_total.loc[stem_workforce_total['Year'] == 1990,'total_num'].values[0]
total_2021 = stem_workforce_total[stem_workforce_total['Year'] == 2021]['total_num'].values[0]
print(total_1990, total_2021)
(total_2021 - total_1990) / total_1990 # increase in percentage
# Out:
# 3304800.0 7709000.0
# 1.3326676349552167

# %% [markdown]
# The popularity of STEM as a field increases between 1990 and 2023 from 3,304,800 to 7,709,000 workers. There are a couple of years where there are dips such as 1997, and 2007, but overall saw an increase of 133.27%.

# %% [markdown]
# ### **2021** STEM Workforce Gender and Ethnicity Distribution
# 2021 marks the most recent year for which we have data on the STEM workforce. We aim to use this information as a basis to explore recent trends in diversity within the STEM field.

# %%
stem_percentage_2021 = stem_percentage[stem_percentage['Year'] == 2021].drop(columns=['Year'])
stem_percentage_2021 = stem_percentage_2021[stem_percentage_2021['Category'] != 'total']
stem_percentage_2021.columns = [x.replace('_percentage','') for x in stem_percentage_2021.columns]

# %%
stem_percentage_2021_eth = stem_percentage_2021.drop(columns=['Female', 'Male'])
stem_percentage_2021_gen = stem_percentage_2021[['Category','Female', 'Male']]

# %%
stem_percentage_2021_eth = stem_percentage_2021_eth[['Category', 'White', 'Asian', 'Hispanic', 'Black', 'More than one race', 'American Indian']]

# %%
# STEM Workforce Distribution by Gender in 2021
ax = stem_percentage_2021_gen.plot(x='Category', kind='bar', stacked=True, figsize=(8, 5), width=0.5, color = ['coral','skyblue'])
ax.set_xlabel('Category', labelpad=20)
ax.set_ylabel('Proportion', labelpad=20)
ax.set_title('STEM Workforce Distribution by Gender in 2021')
ax.legend(title='Gender Group', bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)
plt.xticks(rotation=30, ha='right')
plt.tight_layout()

# %% [markdown]
# Breaking down the STEM workforce by gender and subject reveals that females have higher representation in the social and life sciences, with the social sciences being the only area with more female scientists than males.
#
# We also note that the life sciences having higher female representation compared to other subjects is similar to how there are more female Nobel Prize winners in the medicine category.

# %%
# STEM Workforce Distribution by Ethnicity in 2021
ax = stem_percentage_2021_eth.plot(x='Category', kind='bar', stacked=False, figsize=(8, 5), width=0.8)
ax.set_xlabel('Category', labelpad=20)
ax.set_ylabel('Proportion', labelpad=20)
ax.set_title('STEM Workforce Distribution by Ethnicity in 2021')
ax.legend(title='Ethnicity Group', bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)
plt.xticks(rotation=30, ha='right')
plt.tight_layout()

# %% [markdown]
# In some years, data for American Indian is missing as it was unavailable due to confidentiality or was too small (less than 500). We decided to represent the data during those years as 0 for simplicity's sake. This means that the American Indian would be underrepresented overall, which is shown by the graph above.
# Overall, ethnicity of white is significantly higher than all other races across every categories. It is followed by Asian with second highest presentation in every area except for social sciences, where Hispanics have more distribution than Asian.

# %% [markdown]
# ### **1990-2023** Gender and Ethnicity Distribution of the STEM Workforce

# %%
stem_percentage.columns
# Out:
# Index(['Category', 'Year', 'Hispanic_percentage', 'American Indian_percentage',
#        'Asian_percentage', 'Black_percentage', 'White_percentage',
#        'More than one race_percentage', 'Female_percentage',
#        'Male_percentage'],
#       dtype='object')

# %%
ethnicities_percentage_col = stem_percentage.columns[2:8]
gender_percentage_col = stem_percentage.columns[-2:]

# %%
# Lineplot of Gender Distribution in STEM workforce from 1990-2023
gender_stem = stem_percentage[stem_percentage['Category']=='total'].drop(columns=ethnicities_percentage_col)

plt.figure(figsize=(8, 6))
plt.plot(gender_stem['Year'], gender_stem['Female_percentage'], marker='.', linestyle='-', label='Female proportion', color = 'coral')
plt.plot(gender_stem['Year'], gender_stem['Male_percentage'], marker='.', linestyle='-', label='Male proportion', color = 'skyblue')
plt.title('Gender Diversity Trend in STEM workforce from 1990-2023')
plt.grid(True)
plt.legend()
plt.xlabel('Year')
plt.ylabel('Proportion')
plt.show()

# %% [markdown]
# The percentage of males goes down from ~80% to ~70% and the percent of femalse goes from ~21% to 30% during 1990-2023. This demonstrates a general treand of increase in female representation in STEM workforce.

# %%
# Lineplot of Gender Distribution in STEM workforce from 1990-2023
eth_stem = stem_percentage[stem_percentage['Category']=='total'].drop(columns=gender_percentage_col)

plt.figure(figsize=(8, 6))
for col in eth_stem.columns[2:]:
    label = '_'.join(col.split('_')[:-1])
    plt.plot(eth_stem['Year'], eth_stem[col], marker='.', linestyle='-', label=label)
plt.title('Ethnicity Diversity Trend in STEM workforce from 1990-2023')
plt.grid(True)
plt.legend()
plt.xlabel('Year')
plt.ylabel('Proportion')
plt.show()

# %% [markdown]
# There is a slight increase in Black and Hispanic percent. Asian percent increase significantly, reflecting the same trends as the Nobel Prize winner data. Again, we see that the White/non-POC percent is still the majority, though it decreased significantly in conjunction.

# %% [markdown]
# # Analysis of Diversity Trends

# %%
# read in the needed datasets
final_nobel_prize = pd.read_csv('data/final_nobel_prize.csv', index_col=0)
final_stem_workforce = pd.read_csv('data/final_stem_workforce.csv', index_col=0)

# %% [markdown]
# ### Adjust Ethnicity in Both Datasets
# In refining the dataset, particularly for the purpose of comparative analysis, we made a decision to classify Nobel Prize winners identified as white under the ethnicity group "Non-POC", standing for not people of color. However, it's important to acknowledge that this approach carries the risk of introducing bias, particularly if the data on the racial or ethnic background of the laureates is inaccurate or incomplete.

# %%
final_stem_workforce = final_stem_workforce.rename(columns={'White':'Non-POC', 'White_percentage':'Non-POC_percentage'})

# %%
final_stem_workforce.head()
# Out:
#       Category  Year  Hispanic  American Indian     Asian    Black    Non-POC  \
# 0  engineering  1990   54600.0           4700.0  119900.0  60000.0  1474900.0
# 1  engineering  1993   39000.0           3000.0  132000.0  37000.0  1128000.0
# 2  engineering  1995   42100.0           3400.0  137400.0  34300.0  1120900.0
# 3  engineering  1997   48600.0           3900.0  152900.0  36400.0  1155100.0
# 4  engineering  1999   49100.0           4100.0  156600.0  37700.0  1122400.0
#
#    More than one race  Hispanic_percentage  American Indian_percentage  \
# 0                 0.0             0.031853                    0.002742
# 1                 0.0             0.029126                    0.002240
# 2                 0.0             0.031463                    0.002541
# 3                 0.0             0.034791                    0.002792
# 4                 0.0             0.035842                    0.002993
#
#    Asian_percentage  Black_percentage  Non-POC_percentage  \
# ...

# %%
if final_nobel_prize['identity'].isnull().any():
    final_nobel_prize.loc[final_nobel_prize['identity'].isnull(), 'identity'] = 'Non-POC'
final_nobel_prize.loc[final_nobel_prize['identity']=='Latin American','identity'] = 'Hispanic'

# %%
final_nobel_prize['identity'].unique()
# Out:
# array(['Non-POC', 'Asian', 'African', 'Hispanic', 'Black'], dtype=object)

# %% [markdown]
# Substitution of Nobel Prize winners marked as "African" with "Non-POC" was conducted to ensure the accuracy of racial and ethnic representation. This decision was prompted by the observation that the classification of "African" did not necessarily align with the individuals' racial or ethnic identities. Upon manual review and verification, it was discovered that these laureates, although connected to Africa by birth or heritage, identified as Jewish, Arab, or white.
#
# <!-- This includes individuals like Max Theiler, who, despite being born in Africa, had Swiss-born parents and identified as white, and others with European or American backgrounds. This meticulous verification process underscores our commitment to precise and respectful representation in our dataset, emphasizing that not all individuals born or raised in Africa identify as people of color (POC). Our goal was to reflect a more nuanced understanding of racial and ethnic identities, particularly in a diverse and complex continent like Africa. -->

# %%
final_nobel_prize.loc[final_nobel_prize['identity'] == 'African','identity'] = 'Non-POC'

# %% [markdown]
# After adjusting, the remaining ethnicities in both of our dataset are "Non-POC", "Asian", "Hispanic", and "Black".

# %%
final_nobel_prize['identity'].unique() # African category removed
# Out:
# array(['Non-POC', 'Asian', 'Hispanic', 'Black'], dtype=object)

# %%
final_nobel_prize.head()
# Out:
#         firstname    surname        born        died      bornCountry  \
# 0  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10          Germany
# 1      Hendrik A.    Lorentz  1853-07-18  1928-02-04  the Netherlands
# 2          Pieter     Zeeman  1865-05-25  1943-10-09  the Netherlands
# 3           Henri  Becquerel  1852-12-15  1908-08-25           France
# 4          Pierre      Curie  1859-05-15  1906-04-19           France
#
#      bornCity gender  year category  \
# 0   Remscheid   male  1901  physics
# 1      Arnhem   male  1902  physics
# 2  Zonnemaire   male  1902  physics
# 3       Paris   male  1903  physics
# 4       Paris   male  1903  physics
#
#                                          affiliation       city  \
# 0                                  Munich University     Munich
# 1                                  Leiden University     Leiden
# 2                               Amsterdam University  Amsterdam
# ...

# %% [markdown]
# ### Reorganize data
#
# For ease of comparison, we've reorganized both datasets into identical forms, which have the year as index and number of individuals under each category in the columns. For consistency in analysis, we filtered the Nobel Prize dataset to retain only those columns that align with those in the STEM workforce dataset, ensuring a direct and meaningful comparison.

# %%
workforce_eth = final_stem_workforce[final_stem_workforce['Category']=='total'][['Year','Asian', 'Hispanic','Non-POC','Black']].set_index('Year')
workforce_gen = final_stem_workforce[final_stem_workforce['Category']=='total'][['Year','Female', 'Male']].set_index('Year')
years = workforce_eth.index

# %% [markdown]
# We've noticed that there are no black STEM Nobel Prize winners within the years that we are investigating. To ensure consistency, we still added the "Black" column filled with 0 into the Nobel dataset.

# %%
nobel_eth = final_nobel_prize[final_nobel_prize['year'].isin(years)].groupby(['year','identity'])['surname'].count().unstack().fillna(0)
nobel_eth['Black'] = 0.0
nobel_gen = final_nobel_prize[final_nobel_prize['year'].isin(years)].groupby(['year','gender'])['surname'].count().unstack().fillna(0)
nobel_gen.columns=['Female', 'Male']

# %%
genders = nobel_gen.columns
ethnicities = nobel_eth.columns

# %% [markdown]
# ## Comparison by Visualization
#
# Firstly, we compared the diversity trends in STEM Nobel Winners and STEM workforce by plotting them on the same plot.

# %%
def extract_percentage(df):
    df = df.copy()
    col_keep = []
    for col in df.columns:
        df[f'{col}_percent'] = df[col]/df.sum(axis=1)
        col_keep.append(f'{col}_percent')
    new_df = df[col_keep]
    return new_df

# %%
workforce_female = extract_percentage(workforce_gen)['Female_percent']
nobel_female = extract_percentage(nobel_gen)['Female_percent']

# %%
# Line chart for trends in female percentage among the STEM Nobel Winners and STEM workforce in the focal years.
plt.plot(workforce_female.index, workforce_female.values, label='STEM Workforce', marker='.', linestyle='-', color='#89ABE3')
plt.plot(nobel_female.index, nobel_female.values, label='Nobel Winners', marker='.', linestyle='-', color='#EA738D') 
plt.title('Female Proportion Trend in STEM Workforce and STEM Nobel Winners')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Proportion')
plt.show()

# %% [markdown]
# The proportion of females making up the STEM fields in the workforce is much higher than the Nobel Prize winners. The workforce line shows an upward trend, while the female representation in STEM Nobel Prizes fluctuates, with no identifiable trend.

# %% [markdown]
# For the next graph, we grouped "Asian," "Hispanic," and "Black" individuals as people of color (POC) for clarity. This enables us to examine the trends in POC representation among STEM Nobel Prize winners and the STEM workforce during the relevant years.

# %%
workforce_poc = extract_percentage(workforce_eth).drop('Non-POC_percent', axis=1).sum(axis=1)
nobel_poc = extract_percentage(nobel_eth).drop('Non-POC_percent', axis=1).sum(axis=1)

# %%
# Line chart for trends in POC percentage among the STEM Nobel Winners and STEM workforce in the focal years.
plt.plot(workforce_poc.index, workforce_poc.values, label='STEM Workforce', marker='.', linestyle='-', color='#89ABE3')
plt.plot(nobel_poc.index, nobel_poc.values, label='Nobel Prize Winners', marker='.', linestyle='-', color='#EA738D') 
plt.title('POC Proportion Trend in STEM Workforce and STEM Nobel Winners')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Proportion')
plt.show()

# %% [markdown]
# There is a slow but steady upward trend of POC representation in the STEM workforce, while it is much more volatile in Nobel Prize winners. There are steep fluctuations, most likely because of the small sample size. However, it looks like POC representation has dropped off after 2015 and is consistently lower than the workforce till 2023.

# %% [markdown]
# ## Chi-squared Test
#
# The Chi-squared test is a statistical method used to evaluate the differences between categorical distributions. Specifically, in the context of comparing diversity across the two populations (STEM Nobel Winners and STEM workforce), this test allows us to examine whether there are significant variations in distribution across different categories, such as gender or ethnicity, over various years. The null hypothesis for this testing posits that there is no significant difference between the two distributions being compared in each focal year. This means, for example, that the proportions of different genders or ethnicities within the workforce would be expected to remain consistent across the years examined, barring any statistically significant deviations detected by the test.

# %% [markdown]
# ### Data Preparation

# %%
workforce_eth.head()
# Out:
#          Asian  Hispanic    Non-POC     Black
# Year
# 1990  206600.0  103500.0  2838100.0  146900.0
# 1993  286000.0  111000.0  2718000.0   90000.0
# 1995  338100.0  119100.0  3138900.0  102000.0
# 1997  356900.0  115200.0  2832200.0  106200.0
# 1999  390500.0  120900.0  2896600.0  121600.0

# %%
nobel_eth.head()
# Out:
# identity  Asian  Hispanic  Non-POC  Black
# year
# 1990        0.0       0.0      9.0    0.0
# 1993        0.0       0.0      8.0    0.0
# 1995        0.0       1.0      8.0    0.0
# 1997        1.0       0.0      8.0    0.0
# 1999        0.0       0.0      5.0    0.0

# %% [markdown]
# To conduct a Chi-squared test, we have prepared data as contingency tables, which organized data into matrices that display the frequency distribution of variables.

# %%
gender_contingency_tables = {}
ethnicity_contingency_tables = {}

# %%
for year in years:
    gender_dist = {'Population': ['Nobel Prize Winners', 'STEM Workforce']}
    ethnicity_dist = {'Population': ['Nobel Prize Winners', 'STEM Workforce']}
    for g in genders:
        gender_dist[g] = [nobel_gen.loc[year, g], workforce_gen.loc[year, g]]
    for e in ethnicities:
        ethnicity_dist[e] = [nobel_eth.loc[year, e], workforce_eth.loc[year, e]]
    gender_contingency_tables[year] = pd.DataFrame.from_dict(gender_dist)
    ethnicity_contingency_tables[year] = pd.DataFrame.from_dict(ethnicity_dist)

# %%
gender_contingency_tables[2019]
# Out:
#             Population     Female       Male
# 0  Nobel Prize Winners        1.0       11.0
# 1       STEM Workforce  2193000.0  5274000.0

# %% [markdown]
# ### Chi-squared Test

# %%
import scipy.stats as stats

# %%
def chi_square(data,attr,year):
    chi2, p, dof, expected = stats.chi2_contingency(data)
    if p < 0.05:
        print(f"Significant difference in {attr} distribution between the two populations in {year}.")
        # only print message out when there is statistically significant results
    return chi2, p

# %%
chi_square_results = pd.DataFrame(columns=['year','p_value','category'])

# %%
for year in years:
    gender_data = np.array(gender_contingency_tables[year].iloc[:,1:])
    chi2_g,p_g = chi_square(gender_data,'gender',year)
    chi_square_results.loc[len(chi_square_results.index)] = [year, p_g, 'gender']
    ethnicity_data = np.array(ethnicity_contingency_tables[year].iloc[:,1:])
    chi2_e,p_e = chi_square(ethnicity_data,'ethnicity',year)
    chi_square_results.loc[len(chi_square_results.index)] = [year, p_e, 'ethnicity']
# Out:
# Significant difference in ethnicity distribution between the two populations in 2008.

# %%
chi_square_results
# Out:
#     year   p_value   category
# 0   1990  0.226177     gender
# 1   1990  0.694042  ethnicity
# 2   1993  0.287881     gender
# 3   1993  0.697723  ethnicity
# 4   1995  0.673734     gender
# 5   1995  0.418912  ethnicity
# 6   1997  0.217521     gender
# 7   1997  0.890714  ethnicity
# 8   1999  0.473756     gender
# 9   1999  0.778846  ethnicity
# 10  2000  0.111919     gender
# 11  2000  0.723155  ethnicity
# 12  2003  0.147301     gender
# 13  2003  0.433922  ethnicity
# 14  2006  0.322259     gender
# 15  2006  0.569252  ethnicity
# 16  2008  0.398275     gender
# 17  2008  0.049775  ethnicity
# 18  2010  0.139737     gender
# 19  2010  0.799580  ethnicity
# 20  2013  0.073427     gender
# 21  2013  0.526712  ethnicity
# 22  2015  0.436042     gender
# 23  2015  0.314881  ethnicity
# 24  2017  0.093956     gender
# 25  2017  0.167437  ethnicity
# 26  2019  0.199476     gender
# 27  2019  0.525229  ethnicity
# 28  2021  0.093011     gender
# 29  2021  0.379664  ethnicity

# %%
# take a closer look at ethnicity distribution in 2008
ethnicity_contingency_tables[2008]
# Out:
#             Population     Asian  Hispanic    Non-POC     Black
# 0  Nobel Prize Winners       5.0       0.0        5.0       0.0
# 1       STEM Workforce  824000.0  239000.0  3502000.0  191000.0

# %% [markdown]
# Except for the 2008 data in ethnicity distribution, our analysis lacks sufficient evidence to reject the null hypothesis – meaning, there is no statistical difference between the diversity trends of the STEM workforce and the STEM Nobel Prize winners. It appears that the diversity trends within Nobel laureates generally mirror those observed in the STEM workforce.

# %% [markdown]
# ## Correlation Analysis
#
# In this part, we aim to investigate the potential correlation between the gender and ethnic composition of the STEM workforce and of the Nobel Prize laureates in the focal years. By analyzing these correlations, we seek to understand whether shifts in the STEM workforce's diversity are mirrored in the demographics of Nobel Prize recipients.
#
# The Pearson correlation coefficient is a statistical measure used to assess the strength and direction of a linear relationship between two continuous variables. This coefficient can range from -1 to 1, where -1 indicates a perfect negative linear relationship, 0 indicates no linear relationship, and 1 indicates a perfect positive linear relationship. Applying this coefficient in our analysis will provide insights into how closely the trends in STEM workforce diversity align with those in Nobel Prize winner demographics.

# %% [markdown]
# ### Data Preparation
#
# For simplicity, we will recalibrate the proportions of these four major ethnic groups by recalculating their percentages within the revised dataset, which excludes some of the smaller ethnic categories.

# %%
dfs = []
for df in [workforce_eth, workforce_gen, nobel_eth, nobel_gen]:
    dfs.append(extract_percentage(df))

# %%
ethnicity_percentage = dfs[0].merge(dfs[2], left_index=True, right_index=True) 
gender_percentage = dfs[1].merge(dfs[3], left_index=True, right_index=True)

# %%
ethnicity_percentage.head()
# Out:
#       Asian_percent_x  Hispanic_percent_x  Non-POC_percent_x  Black_percent_x  \
# Year
# 1990         0.062699            0.031410           0.861309         0.044581
# 1993         0.089236            0.034633           0.848050         0.028081
# 1995         0.091425            0.032206           0.848787         0.027582
# 1997         0.104647            0.033778           0.830435         0.031139
# 1999         0.110636            0.034253           0.820660         0.034451
#
#       Asian_percent_y  Hispanic_percent_y  Non-POC_percent_y  Black_percent_y
# Year
# 1990         0.000000            0.000000           1.000000              0.0
# 1993         0.000000            0.000000           1.000000              0.0
# 1995         0.000000            0.111111           0.878049              0.0
# 1997         0.111111            0.000000           0.878049              0.0
# 1999         0.000000            0.000000           1.000000              0.0

# %% [markdown]
# ### Calculate Coefficient
# We calculated the Pearson's correlation coefficient for each gender and ethnicity category.

# %%
# correlation coefficients of gender categories
for gen in genders:
    data = gender_percentage[[x for x in gender_percentage.columns if gen in x]].reset_index()
    pearson_corr = data[f'{gen}_percent_x'].corr(data[f'{gen}_percent_y'])
    print(f"Pearson's correlation coefficient for {gen}: {pearson_corr}")
# Out:
# Pearson's correlation coefficient for Female: 0.11923317126334279
# Pearson's correlation coefficient for Male: 0.11648593144742872

# %%
# correlation coefficients of ethnicity categories
for ethn in ethnicities:
    data = ethnicity_percentage[[x for x in ethnicity_percentage.columns if ethn in x]].reset_index()
    pearson_corr = data[f'{ethn}_percent_x'].corr(data[f'{ethn}_percent_y'])
    print(f"Pearson's correlation coefficient for {ethn}: {pearson_corr}")
# Out:
# Pearson's correlation coefficient for Asian: 0.49178706889638646
# Pearson's correlation coefficient for Hispanic: -0.2734223249927904
# Pearson's correlation coefficient for Non-POC: 0.3659622381178282
# Pearson's correlation coefficient for Black: nan

# %% [markdown]
# Key observations from our analysis include:
#
# - Asian: With a coefficient of 0.4918, we observe a moderate positive correlation. This suggests a tendency for the proportion of Asian Nobel Prize winners to increase alongside an increase in their representation within the STEM workforce. Although the correlation is moderate, it indicates a notable relationship.
#
# - Black: The result of "nan" (not a number) for Black Nobel Prize winners arises from insufficient data to establish a correlation, mainly due to the absence of Black Nobel laureates in the selected years. This limitation prevents us from computing a meaningful correlation.
#
# - Gender: The analysis shows a very weak positive correlation for both females and males. This indicates a minimal linear relationship between an increase in the gender representation within the STEM workforce and their proportion among Nobel Prize winners. Such findings suggest that the transition from workforce representation to Nobel Prize recognition may be influenced by factors beyond mere numerical representation.
#
# The absence of significant results in some categories can be attributed to the small sample size of Nobel Prize winners in the STEM fields. The Nobel Prize is awarded to only a few individuals each year, leading to zero values in some categories and thereby limiting the scope for establishing robust correlations.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# &emsp;While previous studies have addressed various aspects of the lack of diversity of the Nobel Prize laureates, the current literature lacks a holistic overview of POC representation in the pool of winners. Our research aims to investigate the trend toward diversity for women and POC in the workforce compared to Nobel laureates in the STEM fields from 1990 to 2023. We predicted that there would be diversification among Nobel Prize winners, but might not align with the more rapid changes observed in the broader STEM workforce.\
# &emsp;From the Nobel Prize winner dataset, we saw that males and non-POC were overwhelmingly represented, with females and Asians showing the most increase throughout the years. The same was found in the STEM workforce dataset, including a slight increase in female and Asian representation. When comparing the two datasets together, the Nobel Prize winners had a lower percentage of women; the highest percentage never exceeded 15%, as opposed to the workforce, where it approached 30% in recent years. In terms of ethnicity, comparing the two datasets revealed more extreme fluctuations in POC representation in the Nobel Prize winners. This even surpassed the workforce percentage in certain years. However, we found POC representation in the STEM workforce to steadily increase throughout 1990-2023.\
# &emsp;To further support the graphical comparisons, we conducted a chi-square test and correlation analysis. The chi-square showed that besides 2008, there were no statistically significant variations in gender or ethnicity distribution between the two datasets. From the correlation analysis, we observed a moderate positive correlation for Asian representation, suggesting that there is a tendency for Asian Nobel Prize winners to increase alongside the STEM workforce. There was insufficient data to establish a correlation for Black representation, due to the absence of Black Nobel Prize winners during some years.\
# &emsp;Overall, there is not enough evidence to reject the null hypothesis and it is difficult to determine whether or not the diversity trends of Nobel Prize winners in STEM categories reflect the STEM workforce. We are limited by the small sample size of Nobel Prize winners in the STEM fields and potentially incomplete demographic data of the STEM workforce. There were Pacific Islanders, Native Americans, and other identities not fully captured in our dataset and our resulting analysis. In the future, others may attempt to conduct a similar study with Nobel nominees for a larger sample size and more informative results. Another direction could be to focus on specific fields to the corresponding Nobel Prize category to look into diversity trends for subjects like physics, economics, etc. Future studies should focus on bigger datasets for clearer trends, with more thorough and accurate information on POC demographics. While we were unable to find definite conclusions, we expanded on previous research that only focused on the distribution of gender among Nobel Prize winners. We have shown a comparison of diversity trends between Nobel Prize laureates and the workforce in STEM fields, including gender and ethnicity, which broadens the scope of discussion on this topic.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# &emsp;The proposed Nobel Prize winner dataset is based on open-access information about Nobel Prize winners. Given that Nobel Prize winners are well-documented public figures, their information is accessible online. Similarly, the workforce data is also publicly available and doesn't include any sensitive information. Thus, there should not be any privacy concerns.\
# &emsp;While the Nobel Prize dataset is inherently unbiased as it only contains the facts about the winners, the STEM workforce data could introduce bias. The bias may arise during the sampling process, which can be limited in some segments of the workforce, lacking diversity in job roles and focusing on specific geographical locations. To mitigate the biases and increase the reliability of our findings, we aim to search for comprehensive STEM-related data collected by governmental agencies, such as the U.S. Department of Labor, that is representative of the workforce.\
# &emsp;After inspecting our data, certain individuals whom we gathered data from Wikipedia are Africans born and raised but are not necessarily identified as people of color (POC). This includes individuals like Max Theiler, who, despite being born in Africa, had Swiss-born parents and identified as white, and others with European or American backgrounds. This meticulous verification process underscores our commitment to precise and respectful representation in our dataset. Our goal was to reflect a more nuanced understanding of racial and ethnic identities, particularly in a diverse and complex continent like Africa.\
# &emsp;We also wanted to acknowledge that there might be people who would be of more than one race, American Indian, or Pacific Islander who might not be included due to the lack of data available for the STEM workforce gathered in the National Science Foundation. In addition, the STEM Nobel Prize winner also lacked representation for people with more than one race, American Indians, and Pacific Islanders, so we decided to drop off earlier data to make clearer comparisons. Moreover, the gender representation in both datasets is only binary, excluding people with non-binary gender identities, which we hope for a change to a more inclusive collection of demographic data.\
# &emsp;Although our conclusion doesn’t prove whether or not STEM Nobel Prize winners reflect the STEM workforce, this is mainly because the Nobel Prize is a prestigious award. This would mean that the winners are limited, but the STEM workforce will continue to grow due to population increase. Therefore, this is not a representation of women and POC who are a part of the STEM workforce and Nobel Prize winners and should not be used to judge other women and POC in STEM.

# %% [markdown]
# # Team Contributions
#
# - Anh Tran: Background research, data collecting, forming descriptions, editing graphs, ethics and privacy, slides and video creation.
# - Jodi Roe: Background research and write up for introduction, data visualization descriptions, proofreading and editing coding descriptions, abstract, conclusion/discussion, final slides editing
# - Tianyu Wang: Background write-up, data collection of STEM workforce, editing coding and graph descriptions, slides, video
# - Wan-Hsuan Lin: Background research for introduction, data collection, wrangling, visualizations, and descriptions, video slides and voice recording.
# - Xiaoyu Gui: Research question, hypothesis and team timeline, data collection of Nobel Prize Winners, data merging and cleaning, visualizations, analysis code and descriptions.
